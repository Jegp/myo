# %%
import pandas as pd
import numpy as np
import sklearn, sklearn.ensemble, sklearn.decomposition, sklearn.neighbors, sklearn.model_selection, sklearn.svm
from sklearn.preprocessing import StandardScaler
import baikal, baikal.sklearn

# %%
RandomForest = baikal.make_step(sklearn.ensemble.RandomForestClassifier)

# %%
KNN = baikal.make_step(sklearn.neighbors.KNeighborsClassifier)

# %%
SVM = baikal.make_step(sklearn.svm.SVC)

# %%
PCA = baikal.make_step(sklearn.decomposition.PCA)

# %%
Scaler = baikal.make_step(StandardScaler)

# %%
X = np.load('X.npy')

# %%
Y = np.load('Y.npy')

# %%
X.size
# Out:
# 16032

# %%
SEED = 5321

# %%
def build():
    x = baikal.Input()
    y_t = baikal.Input()
    x_s = Scaler(name="scaler")(x)
    y_p = SVM(random_state=SEED, name="classifier")(x_s, y_t)
    model = baikal.Model(x, y_p, y_t)
    return model

def build_pca():
    x = baikal.Input()
    y_t = baikal.Input()
    x_s = Scaler(name="scaler")(x)
    h = PCA(random_state=SEED, name="pca")(x_s)
    y_p = SVM(random_state=SEED, name="classifier")(h, y_t)
    model = baikal.Model(x, y_p, y_t)
    return model

# %%
param_grid = [
    {
        "classifier": [
            SVM(random_state=SEED)
        ],
        "classifier__C": [0.01, 0.1, 1],
        "classifier__kernel": ["rbf", "poly", "sigmoid"],
    },
    {
        "classifier": [
            KNN()
        ],
        "classifier__n_neighbors": [3, 4, 5, 6, 7],
        "classifier__weights": ["distance", "uniform"],
    },
    {
        "classifier": [RandomForest(random_state=SEED)],
        "classifier__n_estimators": [10, 50, 100, 150, 200, 250],
    },
]

# %%
param_grid_pca = [
    {
        "classifier": [
            SVM(random_state=SEED)
        ],
        "classifier__C": [0.01, 0.1, 1],
        "classifier__kernel": ["rbf", "poly", "sigmoid"],
        "pca__n_components": [1, 2, 3, 4, 5],
    },
    {
        "classifier": [
            KNN()
        ],
        "classifier__n_neighbors": [3, 4, 5, 6, 7],
        "classifier__weights": ["distance", "uniform"],
        "pca__n_components": [1, 2, 3, 4, 5],
    },
    {
        "classifier": [RandomForest(random_state=SEED)],
        "classifier__n_estimators": [10, 50, 100, 150, 200, 250],
        "pca__n_components": [1, 2, 3, 4, 5],
    },
]

# %%
cv = sklearn.model_selection.StratifiedKFold(n_splits=3, random_state=SEED)
# Out:
# /home/jens/.venvs/myo/lib/python3.8/site-packages/sklearn/model_selection/_split.py:292: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(

# %%
raw_model = baikal.sklearn.SKLearnWrapper(build)
pca_model = baikal.sklearn.SKLearnWrapper(build_pca)

# %%
raw_baikal = sklearn.model_selection.GridSearchCV(
    raw_model,
    param_grid,
    cv=cv,
    scoring="accuracy",
    return_train_score=True
)

# %%
raw_baikal.fit(X, Y)
print("Best score:", raw_baikal.best_score_)
print("Best parameters", raw_baikal.best_params_)
# Out:
# Best score: 0.9925149700598803
# Best parameters {'classifier': RandomForestClassifier(name='classifier', n_outputs=1,
# bootstrap=True, ccp_alpha=0.0, class_weight=None, criterion='gini', max_depth=None, max_features='auto', max_leaf_nodes=None, max_samples=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None, oob_score=False, random_state=5321, verbose=0, warm_start=False), 'classifier__n_estimators': 200}

# %%
pca_baikal = sklearn.model_selection.GridSearchCV(
    pca_model,
    param_grid_pca,
    cv=cv,
    scoring="accuracy",
    return_train_score=True
)

# %%
pca_baikal.fit(X, Y)
print("Best score:", pca_baikal.best_score_)
print("Best parameters", pca_baikal.best_params_)
# Out:
# Best score: 0.9805389221556887
# Best parameters {'classifier': SVC(name='classifier', n_outputs=1,
# C=0.1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0, decision_function_shape='ovr', degree=3, gamma='scale', kernel='sigmoid', max_iter=-1, probability=False, random_state=5321, shrinking=True, tol=0.001, verbose=False), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid', 'pca__n_components': 5}

# %%
pca_baikal.best_estimator_.model.predict(X[:1])
# Out:
# array([0])

# %%
pd.DataFrame(pca_baikal.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.084395      0.002980         0.032323        0.001901
# 1         0.067659      0.004856         0.030775        0.002199
# 2         0.066872      0.005893         0.027699        0.001083
# 3         0.074334      0.003756         0.028145        0.001763
# 4         0.079304      0.004570         0.030030        0.001234
# ..             ...           ...              ...             ...
# 120       0.490487      0.023547         0.031768        0.000420
# 121       0.397853      0.005448         0.022130        0.000212
# 122       0.424987      0.006832         0.022218        0.000213
# 123       0.512545      0.105902         0.020851        0.000151
# 124       0.454570      0.008971         0.020895        0.000135
#
#                                       param_classifier param_classifier__C  \
# 0    SVC(name='classifier', n_outputs=1,\nC=0.1, br...                0.01
# 1    SVC(name='classifier', n_outputs=1,\nC=0.1, br...                0.01
# 2    SVC(name='classifier', n_outputs=1,\nC=0.1, br...                0.01
# 3    SVC(name='classifier', n_outputs=1,\nC=0.1, br...                0.01
# 4    SVC(name='classifier', n_outputs=1,\nC=0.1, br...                0.01
# ..                                                 ...                 ...
# 120  RandomForestClassifier(name='RandomForestClass...                 NaN
# 121  RandomForestClassifier(name='RandomForestClass...                 NaN
# 122  RandomForestClassifier(name='RandomForestClass...                 NaN
# 123  RandomForestClassifier(name='RandomForestClass...                 NaN
# 124  RandomForestClassifier(name='RandomForestClass...                 NaN
#
#     param_classifier__kernel param_pca__n_components  \
# 0                        rbf                       1
# 1                        rbf                       2
# 2                        rbf                       3
# 3                        rbf                       4
# 4                        rbf                       5
# ..                       ...                     ...
# 120                      NaN                       1
# 121                      NaN                       2
# 122                      NaN                       3
# 123                      NaN                       4
# 124                      NaN                       5
#
#     param_classifier__n_neighbors param_classifier__weights  ...  \
# 0                             NaN                       NaN  ...
# 1                             NaN                       NaN  ...
# 2                             NaN                       NaN  ...
# 3                             NaN                       NaN  ...
# 4                             NaN                       NaN  ...
# ..                            ...                       ...  ...
# 120                           NaN                       NaN  ...
# 121                           NaN                       NaN  ...
# 122                           NaN                       NaN  ...
# 123                           NaN                       NaN  ...
# 124                           NaN                       NaN  ...
#
#     split1_test_score split2_test_score  mean_test_score  std_test_score  \
# 0            0.609281          0.666168         0.648703        0.027935
# 1            0.970060          0.920659         0.958583        0.027504
# 2            0.956587          0.929641         0.954591        0.019608
# 3            0.983533          0.953593         0.972555        0.013464
# 4            0.988024          0.952096         0.973054        0.015267
# ..                ...               ...              ...             ...
# 120          0.649701          0.517964         0.596307        0.056601
# 121          0.979042          0.896707         0.952595        0.039538
# 122          0.979042          0.943114         0.970060        0.019403
# 123          0.979042          0.914671         0.957086        0.029998
# 124          0.986527          0.932635         0.969561        0.026139
#
#      rank_test_score  split0_train_score  split1_train_score  \
# 0                103            0.677395            0.699102
# 1                 75            0.954341            0.957335
# 2                 82            0.965569            0.961826
# 3                 16            0.979042            0.976796
# 4                 15            0.979790            0.982036
# ..               ...                 ...                 ...
# 120              118            1.000000            1.000000
# 121               86            1.000000            1.000000
# 122               40            1.000000            1.000000
# 123               77            1.000000            1.000000
# 124               41            1.000000            1.000000
#
#      split2_train_score  mean_train_score  std_train_score
# 0              0.671407          0.682635         0.011898
# 1              0.983533          0.965070         0.013112
# 2              0.975299          0.967565         0.005679
# 3              0.991766          0.982535         0.006592
# 4              0.991766          0.984531         0.005198
# ..                  ...               ...              ...
# 120            1.000000          1.000000         0.000000
# 121            1.000000          1.000000         0.000000
# 122            1.000000          1.000000         0.000000
# 123            1.000000          1.000000         0.000000
# 124            1.000000          1.000000         0.000000
#
# [125 rows x 23 columns]

# %%
def classifier_latex(df, with_pca=False):
    pf = "param_classifier__"
    pc = "param_pca__"
    classifiers = []
    for row in pd.DataFrame(df).iterrows():
        r = row[1]
        classifier = str(row[1]['param_classifier'])
        if "SVC" in classifier:
            text = ["SVM", f"C: {r[pf + 'C']}", f"Kernel: {r[pf + 'kernel']}"]
        if "KNeighbors" in classifier:
            text = ["KNN", f"N: {r[pf + 'n_neighbors']}", f"Weights: {r[pf + 'weights']}"]
        if "Forest" in classifier:
            text = ["RF", f"N: {r[pf + 'n_estimators']}", ""]
        if with_pca:
            text.append(f"K: {r[pc + 'n_components']}")

        classifiers.append(text + [f"{r['mean_test_score']:.3f} $\pm$ {r['std_test_score']:.3f}"])
        
    columns = ["Classifier", "Parameters", "", "Score"]
    if with_pca:
        columns.insert(2, "PCA components")
    return pd.DataFrame(classifiers, columns=columns).to_latex(escape=False, index=False)

# %%
print(classifier_latex(raw_baikal.cv_results_))
# Out:
# \begin{tabular}{llll}
# \toprule
# Classifier & \multicolumn{2}{l}{Parameters} &              Score \\
# \midrule
#        SVM &    C: 0.01 &        Kernel: rbf &  0.975 $\pm$ 0.013 \\
#        SVM &    C: 0.01 &       Kernel: poly &  0.879 $\pm$ 0.035 \\
#        SVM &    C: 0.01 &    Kernel: sigmoid &  0.975 $\pm$ 0.011 \\
#        SVM &     C: 0.1 &        Kernel: rbf &  0.989 $\pm$ 0.003 \\
#        SVM &     C: 0.1 &       Kernel: poly &  0.975 $\pm$ 0.009 \\
#        SVM &     C: 0.1 &    Kernel: sigmoid &  0.989 $\pm$ 0.009 \\
#        SVM &       C: 1 &        Kernel: rbf &  0.985 $\pm$ 0.007 \\
#        SVM &       C: 1 &       Kernel: poly &  0.985 $\pm$ 0.008 \\
#        SVM &       C: 1 &    Kernel: sigmoid &  0.989 $\pm$ 0.004 \\
#        KNN &       N: 3 &  Weights: distance &  0.983 $\pm$ 0.007 \\
#        KNN &       N: 3 &   Weights: uniform &  0.984 $\pm$ 0.006 \\
#        KNN &       N: 4 &  Weights: distance &  0.984 $\pm$ 0.006 \\
#        KNN &       N: 4 &   Weights: uniform &  0.985 $\pm$ 0.006 \\
#        KNN &       N: 5 &  Weights: distance &  0.984 $\pm$ 0.006 \\
#        KNN &       N: 5 &   Weights: uniform &  0.984 $\pm$ 0.006 \\
#        KNN &       N: 6 &  Weights: distance &  0.984 $\pm$ 0.006 \\
#        KNN &       N: 6 &   Weights: uniform &  0.985 $\pm$ 0.005 \\
#        KNN &       N: 7 &  Weights: distance &  0.985 $\pm$ 0.005 \\
#        KNN &       N: 7 &   Weights: uniform &  0.985 $\pm$ 0.005 \\
#         RF &      N: 10 &                    &  0.972 $\pm$ 0.008 \\
#         RF &      N: 50 &                    &  0.989 $\pm$ 0.008 \\
#         RF &     N: 100 &                    &  0.991 $\pm$ 0.006 \\
#         RF &     N: 150 &                    &  0.992 $\pm$ 0.006 \\
#         RF &     N: 200 &                    &  0.993 $\pm$ 0.006 \\
#         RF &     N: 250 &                    &  0.993 $\pm$ 0.006 \\
# \bottomrule
# \end{tabular}

# %%
print(classifier_latex(pca_baikal.cv_results_, True))
# Out:
# \begin{tabular}{lllll}
# \toprule
# Classifier & Parameters & \multicolumn{2}{l}{PCA components} &              Score \\
# \midrule
#        SVM &    C: 0.01 &        Kernel: rbf &  K: 1 &  0.649 $\pm$ 0.028 \\
#        SVM &    C: 0.01 &        Kernel: rbf &  K: 2 &  0.959 $\pm$ 0.028 \\
#        SVM &    C: 0.01 &        Kernel: rbf &  K: 3 &  0.955 $\pm$ 0.020 \\
#        SVM &    C: 0.01 &        Kernel: rbf &  K: 4 &  0.973 $\pm$ 0.013 \\
#        SVM &    C: 0.01 &        Kernel: rbf &  K: 5 &  0.973 $\pm$ 0.015 \\
#        SVM &    C: 0.01 &       Kernel: poly &  K: 1 &  0.594 $\pm$ 0.042 \\
#        SVM &    C: 0.01 &       Kernel: poly &  K: 2 &  0.833 $\pm$ 0.058 \\
#        SVM &    C: 0.01 &       Kernel: poly &  K: 3 &  0.876 $\pm$ 0.040 \\
#        SVM &    C: 0.01 &       Kernel: poly &  K: 4 &  0.881 $\pm$ 0.041 \\
#        SVM &    C: 0.01 &       Kernel: poly &  K: 5 &  0.884 $\pm$ 0.041 \\
#        SVM &    C: 0.01 &    Kernel: sigmoid &  K: 1 &  0.488 $\pm$ 0.015 \\
#        SVM &    C: 0.01 &    Kernel: sigmoid &  K: 2 &  0.947 $\pm$ 0.029 \\
#        SVM &    C: 0.01 &    Kernel: sigmoid &  K: 3 &  0.951 $\pm$ 0.026 \\
#        SVM &    C: 0.01 &    Kernel: sigmoid &  K: 4 &  0.971 $\pm$ 0.011 \\
#        SVM &    C: 0.01 &    Kernel: sigmoid &  K: 5 &  0.973 $\pm$ 0.011 \\
#        SVM &     C: 0.1 &        Kernel: rbf &  K: 1 &  0.664 $\pm$ 0.023 \\
#        SVM &     C: 0.1 &        Kernel: rbf &  K: 2 &  0.962 $\pm$ 0.027 \\
#        SVM &     C: 0.1 &        Kernel: rbf &  K: 3 &  0.975 $\pm$ 0.021 \\
#        SVM &     C: 0.1 &        Kernel: rbf &  K: 4 &  0.975 $\pm$ 0.017 \\
#        SVM &     C: 0.1 &        Kernel: rbf &  K: 5 &  0.978 $\pm$ 0.018 \\
#        SVM &     C: 0.1 &       Kernel: poly &  K: 1 &  0.628 $\pm$ 0.045 \\
#        SVM &     C: 0.1 &       Kernel: poly &  K: 2 &  0.872 $\pm$ 0.069 \\
#        SVM &     C: 0.1 &       Kernel: poly &  K: 3 &  0.931 $\pm$ 0.010 \\
#        SVM &     C: 0.1 &       Kernel: poly &  K: 4 &  0.956 $\pm$ 0.020 \\
#        SVM &     C: 0.1 &       Kernel: poly &  K: 5 &  0.959 $\pm$ 0.021 \\
#        SVM &     C: 0.1 &    Kernel: sigmoid &  K: 1 &  0.496 $\pm$ 0.030 \\
#        SVM &     C: 0.1 &    Kernel: sigmoid &  K: 2 &  0.969 $\pm$ 0.030 \\
#        SVM &     C: 0.1 &    Kernel: sigmoid &  K: 3 &  0.973 $\pm$ 0.024 \\
#        SVM &     C: 0.1 &    Kernel: sigmoid &  K: 4 &  0.980 $\pm$ 0.019 \\
#        SVM &     C: 0.1 &    Kernel: sigmoid &  K: 5 &  0.981 $\pm$ 0.018 \\
#        SVM &       C: 1 &        Kernel: rbf &  K: 1 &  0.668 $\pm$ 0.022 \\
#        SVM &       C: 1 &        Kernel: rbf &  K: 2 &  0.966 $\pm$ 0.018 \\
#        SVM &       C: 1 &        Kernel: rbf &  K: 3 &  0.975 $\pm$ 0.014 \\
#        SVM &       C: 1 &        Kernel: rbf &  K: 4 &  0.974 $\pm$ 0.016 \\
#        SVM &       C: 1 &        Kernel: rbf &  K: 5 &  0.974 $\pm$ 0.019 \\
#        SVM &       C: 1 &       Kernel: poly &  K: 1 &  0.631 $\pm$ 0.054 \\
#        SVM &       C: 1 &       Kernel: poly &  K: 2 &  0.937 $\pm$ 0.044 \\
#        SVM &       C: 1 &       Kernel: poly &  K: 3 &  0.968 $\pm$ 0.006 \\
#        SVM &       C: 1 &       Kernel: poly &  K: 4 &  0.972 $\pm$ 0.019 \\
#        SVM &       C: 1 &       Kernel: poly &  K: 5 &  0.974 $\pm$ 0.019 \\
#        SVM &       C: 1 &    Kernel: sigmoid &  K: 1 &  0.381 $\pm$ 0.098 \\
#        SVM &       C: 1 &    Kernel: sigmoid &  K: 2 &  0.937 $\pm$ 0.017 \\
#        SVM &       C: 1 &    Kernel: sigmoid &  K: 3 &  0.972 $\pm$ 0.011 \\
#        SVM &       C: 1 &    Kernel: sigmoid &  K: 4 &  0.975 $\pm$ 0.013 \\
#        SVM &       C: 1 &    Kernel: sigmoid &  K: 5 &  0.979 $\pm$ 0.014 \\
#        KNN &       N: 3 &  Weights: distance &  K: 1 &  0.607 $\pm$ 0.051 \\
#        KNN &       N: 3 &  Weights: distance &  K: 2 &  0.960 $\pm$ 0.025 \\
#        KNN &       N: 3 &  Weights: distance &  K: 3 &  0.972 $\pm$ 0.017 \\
#        KNN &       N: 3 &  Weights: distance &  K: 4 &  0.969 $\pm$ 0.019 \\
#        KNN &       N: 3 &  Weights: distance &  K: 5 &  0.969 $\pm$ 0.021 \\
#        KNN &       N: 3 &   Weights: uniform &  K: 1 &  0.623 $\pm$ 0.056 \\
#        KNN &       N: 3 &   Weights: uniform &  K: 2 &  0.961 $\pm$ 0.022 \\
#        KNN &       N: 3 &   Weights: uniform &  K: 3 &  0.975 $\pm$ 0.013 \\
#        KNN &       N: 3 &   Weights: uniform &  K: 4 &  0.973 $\pm$ 0.013 \\
#        KNN &       N: 3 &   Weights: uniform &  K: 5 &  0.973 $\pm$ 0.016 \\
#        KNN &       N: 4 &  Weights: distance &  K: 1 &  0.608 $\pm$ 0.055 \\
#        KNN &       N: 4 &  Weights: distance &  K: 2 &  0.961 $\pm$ 0.024 \\
#        KNN &       N: 4 &  Weights: distance &  K: 3 &  0.972 $\pm$ 0.014 \\
#        KNN &       N: 4 &  Weights: distance &  K: 4 &  0.969 $\pm$ 0.018 \\
#        KNN &       N: 4 &  Weights: distance &  K: 5 &  0.971 $\pm$ 0.020 \\
#        KNN &       N: 4 &   Weights: uniform &  K: 1 &  0.616 $\pm$ 0.062 \\
#        KNN &       N: 4 &   Weights: uniform &  K: 2 &  0.962 $\pm$ 0.021 \\
#        KNN &       N: 4 &   Weights: uniform &  K: 3 &  0.974 $\pm$ 0.009 \\
#        KNN &       N: 4 &   Weights: uniform &  K: 4 &  0.973 $\pm$ 0.013 \\
#        KNN &       N: 4 &   Weights: uniform &  K: 5 &  0.975 $\pm$ 0.013 \\
#        KNN &       N: 5 &  Weights: distance &  K: 1 &  0.610 $\pm$ 0.055 \\
#        KNN &       N: 5 &  Weights: distance &  K: 2 &  0.963 $\pm$ 0.024 \\
#        KNN &       N: 5 &  Weights: distance &  K: 3 &  0.971 $\pm$ 0.015 \\
#        KNN &       N: 5 &  Weights: distance &  K: 4 &  0.968 $\pm$ 0.020 \\
#        KNN &       N: 5 &  Weights: distance &  K: 5 &  0.972 $\pm$ 0.017 \\
#        KNN &       N: 5 &   Weights: uniform &  K: 1 &  0.626 $\pm$ 0.061 \\
#        KNN &       N: 5 &   Weights: uniform &  K: 2 &  0.964 $\pm$ 0.023 \\
#        KNN &       N: 5 &   Weights: uniform &  K: 3 &  0.972 $\pm$ 0.013 \\
#        KNN &       N: 5 &   Weights: uniform &  K: 4 &  0.970 $\pm$ 0.018 \\
#        KNN &       N: 5 &   Weights: uniform &  K: 5 &  0.971 $\pm$ 0.018 \\
#        KNN &       N: 6 &  Weights: distance &  K: 1 &  0.610 $\pm$ 0.054 \\
#        KNN &       N: 6 &  Weights: distance &  K: 2 &  0.964 $\pm$ 0.023 \\
#        KNN &       N: 6 &  Weights: distance &  K: 3 &  0.972 $\pm$ 0.013 \\
#        KNN &       N: 6 &  Weights: distance &  K: 4 &  0.969 $\pm$ 0.018 \\
#        KNN &       N: 6 &  Weights: distance &  K: 5 &  0.972 $\pm$ 0.018 \\
#        KNN &       N: 6 &   Weights: uniform &  K: 1 &  0.626 $\pm$ 0.067 \\
#        KNN &       N: 6 &   Weights: uniform &  K: 2 &  0.967 $\pm$ 0.019 \\
#        KNN &       N: 6 &   Weights: uniform &  K: 3 &  0.973 $\pm$ 0.011 \\
#        KNN &       N: 6 &   Weights: uniform &  K: 4 &  0.968 $\pm$ 0.017 \\
#        KNN &       N: 6 &   Weights: uniform &  K: 5 &  0.972 $\pm$ 0.015 \\
#        KNN &       N: 7 &  Weights: distance &  K: 1 &  0.616 $\pm$ 0.057 \\
#        KNN &       N: 7 &  Weights: distance &  K: 2 &  0.966 $\pm$ 0.021 \\
#        KNN &       N: 7 &  Weights: distance &  K: 3 &  0.973 $\pm$ 0.011 \\
#        KNN &       N: 7 &  Weights: distance &  K: 4 &  0.968 $\pm$ 0.018 \\
#        KNN &       N: 7 &  Weights: distance &  K: 5 &  0.971 $\pm$ 0.020 \\
#        KNN &       N: 7 &   Weights: uniform &  K: 1 &  0.630 $\pm$ 0.066 \\
#        KNN &       N: 7 &   Weights: uniform &  K: 2 &  0.965 $\pm$ 0.017 \\
#        KNN &       N: 7 &   Weights: uniform &  K: 3 &  0.971 $\pm$ 0.012 \\
#        KNN &       N: 7 &   Weights: uniform &  K: 4 &  0.967 $\pm$ 0.019 \\
#        KNN &       N: 7 &   Weights: uniform &  K: 5 &  0.971 $\pm$ 0.020 \\
#         RF &      N: 10 &                    &  K: 1 &  0.598 $\pm$ 0.059 \\
#         RF &      N: 10 &                    &  K: 2 &  0.947 $\pm$ 0.041 \\
#         RF &      N: 10 &                    &  K: 3 &  0.959 $\pm$ 0.028 \\
#         RF &      N: 10 &                    &  K: 4 &  0.955 $\pm$ 0.025 \\
#         RF &      N: 10 &                    &  K: 5 &  0.961 $\pm$ 0.024 \\
#         RF &      N: 50 &                    &  K: 1 &  0.597 $\pm$ 0.057 \\
#         RF &      N: 50 &                    &  K: 2 &  0.952 $\pm$ 0.039 \\
#         RF &      N: 50 &                    &  K: 3 &  0.967 $\pm$ 0.022 \\
#         RF &      N: 50 &                    &  K: 4 &  0.954 $\pm$ 0.035 \\
#         RF &      N: 50 &                    &  K: 5 &  0.965 $\pm$ 0.033 \\
#         RF &     N: 100 &                    &  K: 1 &  0.596 $\pm$ 0.057 \\
#         RF &     N: 100 &                    &  K: 2 &  0.953 $\pm$ 0.038 \\
#         RF &     N: 100 &                    &  K: 3 &  0.965 $\pm$ 0.026 \\
#         RF &     N: 100 &                    &  K: 4 &  0.956 $\pm$ 0.032 \\
#         RF &     N: 100 &                    &  K: 5 &  0.969 $\pm$ 0.027 \\
#         RF &     N: 150 &                    &  K: 1 &  0.596 $\pm$ 0.057 \\
#         RF &     N: 150 &                    &  K: 2 &  0.953 $\pm$ 0.038 \\
#         RF &     N: 150 &                    &  K: 3 &  0.965 $\pm$ 0.027 \\
#         RF &     N: 150 &                    &  K: 4 &  0.955 $\pm$ 0.033 \\
#         RF &     N: 150 &                    &  K: 5 &  0.969 $\pm$ 0.026 \\
#         RF &     N: 200 &                    &  K: 1 &  0.596 $\pm$ 0.057 \\
#         RF &     N: 200 &                    &  K: 2 &  0.953 $\pm$ 0.038 \\
#         RF &     N: 200 &                    &  K: 3 &  0.968 $\pm$ 0.023 \\
#         RF &     N: 200 &                    &  K: 4 &  0.957 $\pm$ 0.031 \\
#         RF &     N: 200 &                    &  K: 5 &  0.969 $\pm$ 0.027 \\
#         RF &     N: 250 &                    &  K: 1 &  0.596 $\pm$ 0.057 \\
#         RF &     N: 250 &                    &  K: 2 &  0.953 $\pm$ 0.040 \\
#         RF &     N: 250 &                    &  K: 3 &  0.970 $\pm$ 0.019 \\
#         RF &     N: 250 &                    &  K: 4 &  0.957 $\pm$ 0.030 \\
#         RF &     N: 250 &                    &  K: 5 &  0.970 $\pm$ 0.026 \\
# \bottomrule
# \end{tabular}

# %%
from sklearn.metrics import classification_report
print(classification_report(Y, raw_baikal.best_estimator_.predict(X)))
print(classification_report(Y, pca_baikal.best_estimator_.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       501
#            1       1.00      1.00      1.00       501
#            2       1.00      1.00      1.00       501
#            3       1.00      1.00      1.00       501
#
#     accuracy                           1.00      2004
#    macro avg       1.00      1.00      1.00      2004
# weighted avg       1.00      1.00      1.00      2004
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       501
#            1       0.98      1.00      0.99       501
#            2       0.98      1.00      0.99       501
#            3       1.00      0.99      1.00       501
#
#     accuracy                           0.99      2004
#    macro avg       0.99      0.99      0.99      2004
# weighted avg       0.99      0.99      0.99      2004
